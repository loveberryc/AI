# %% [markdown]
# ## python version
#
# * 2.7
# * 3.9
#
# `python --version`

# %% [markdown]
# # Hello world

# %%
# print("HELLO WORLD")

print("hello world")
# Out:
# hello world

# %%
print("hello world")

print("-------------------------")

print("Hello AI")
# Out:
# hello world
# -------------------------
# Hello AI

# %%
#Multiple Statements on a Single Line
print("hello world"); print("-------------------------"); print("Hello AI")
# Out:
# hello world
# -------------------------
# Hello AI

# %% [markdown]
# # variables
#
# ## name
#
# * keywords   `help('keywords')`
#
# * Camel-Case, Pascal-case, Hungarian

# %%
help('keywords')
# Out:
# Here is a list of the Python keywords.  Enter any keyword to get more help.
#
# False               break               for                 not
# None                class               from                or
# True                continue            global              pass
# __peg_parser__      def                 if                  raise
# and                 del                 import              return
# as                  elif                in                  try
# assert              else                is                  while
# async               except              lambda              with
# await               finally             nonlocal            yield

# %%
#Camel-Case
studentAge = 20
student_age = 20

#Pascal
StudentAge = 20

#Hungarian
i_studentAge = 20

print(student_age)
print(type(student_age))
# Out:
# 20
# <class 'int'>

# %% [markdown]
# ## type
# * Numbers: int, float, uint, double...
# * Boolean
# * String
# * List
# * Tuple
# * Dictionary

# %% [markdown]
# ### numbers and Arithmetic Operators: + - * ** / // %

# %%
# numbers
# Arithmetic Operators: + - * ** / // %
student_age = 20

print(type(student_age))

house_price = 8.3

print(type(house_price))
# Out:
# <class 'int'>
# <class 'float'>

# %%
a = student_age + house_price

print(type(a))
# Out:
# <class 'float'>

# %%
2**3
# Out:
# 8

# %%
7 % 4
# Out:
# 3

# %% [markdown]
# ### bool and Comparison Operators
#
# * ==	If the values of two operands are equal, then the condition becomes true.	(a == b) is not true.
# * !=	If values of two operands are not equal, then condition becomes true.	(a != b) is true.
# * <>	If values of two operands are not equal, then condition becomes true.	(a <> b) is true. This is similar to != operator.
# * <	If the value of left operand is less than the value of right operand, then condition becomes true.	(a < b) is true.
# * `>=`	If the value of left operand is greater than or equal to the value of right operand, then condition becomes true.	(a >= b) is not true.
# * `<=`	If the value of left operand is less than or equal to the value of right operand, then condition becomes true.	(a <= b) is

# %%
a = False
b = True

c = 5
d = 9
c = c < d
print(c)
# Out:
# True

# %% [markdown]
# # condition control
#
# <img src="./images/decision_making.jpg" width="25%">

# %%
lowest_price = 2
current_price = 3
condition = current_price < lowest_price
if (condition):
    print("True") # Indentation
else:
    print("False")
# Out:
# False

# %% [markdown]
# ## Indentation
# * Indentation is to determine the grouping of statements.
# * one `tab` or `four spaces`

# %%
condition = False
if (condition):
    print("True")
    print("code block for True")
    print("indent is used to identify code blocks")
    print("common indent: four space")
else:
    print("False")
    print("code block for False")
# Out:
# False
# code block for False

# %%
lowest_price = 2
current_price = 1
condition = current_price < lowest_price
if (condition):
    print("True")
    lowest_price = current_price
else:
    print("False")
print(lowest_price)
# Out:
# True
# 1

# %% [markdown]
# # list
# * The list is written as a list of comma-separated values (items) between square brackets.
# * Important thing about a list is that items in a list need not be of the same type.
# * the index of list items starts from 0.
#
# <img src="./images/list.jpg" width="50%">

# %%
a = [5, 3, 1.3, 0, -5, "AI"]
print(a)
# Out:
# [5, 3, 1.3, 0, -5, 'AI']

# %%
# Accessing Values in Lists by index
print(a[0], a[2], a[-2])
# Out:
# 5 1.3 -5

# %%
# length of list
# last item
# len, -1

print("length of list a is ", len(a))
print("the last item in list a is ", a[len(a) - 1], a[-1])
# Out:
# length of list a is  6
# the last item in list a is  AI AI

# %% [markdown]
# ## slicing  `a[start_idx : end_idx]`
#
#
# <img src="./images/list-a.jpg" width="40%">

# %%
# slicing
# [start, end )
print(a[2 : 4])
print(a[-4 : -2])
# Out:
# [1.3, 0]
# [1.3, 0]

# %%
print(a[: 4])
print(a[2: ])
# Out:
# [5, 3, 1.3, 0]
# [1.3, 0, -5, 'AI']

# %%
print(a[-4: ])
print(a[: -2])
# Out:
# [1.3, 0, -5, 'AI']
# [5, 3, 1.3, 0]

# %%
print(a[4 : 2])
print(a[-2 : -4])
# Out:
# []
# []

# %% [markdown]
# ## slicing with skip  `a[start_idx : end_idx : skip]`
# <img src="./images/list-b.jpg" width="40%">

# %%
print(a[ 1: 5: 2])
print(a[ 1: 5: 3])
# Out:
# [3, 0]
# [3, -5]

# %%
print(a[ 1: 5: 4])
# Out:
# [3]

# %%
print(a[ 1: 6: 4])
# Out:
# [3, 'AI']

# %% [markdown]
# ## change list
#
# <img src="./images/list-c.jpg" width="40%">

# %%
a.append(10)
print(a)
# Out:
# [5, 3, 1.3, 0, -5, 'AI', 10]

# %%
a.insert(2, 10)
print(a)
# Out:
# [5, 3, 10, 1.3, 0, -5, 'AI', 10]

# %%
a.remove(-5)
print(a)
# Out:
# [5, 3, 10, 1.3, 0, 'AI', 10]

# %%
a.remove(10)
print(a)
# Out:
# [5, 3, 1.3, 0, 'AI', 10]

# %% [markdown]
# ## some useful function of list
# * `max()`
# * `min()`
# * `len()`

# %%
price_list = [9,7,4,6,7,8,6,8,4,7,5]
max(price_list), min(price_list)
# Out:
# (9, 4)

# %% [markdown]
# # for loop

# %%
price_list = [9,7,4,6,7,8,6,8,4,7,5]
lowest_price = 1000
for current_price in price_list:
    condition = current_price < lowest_price
    if (condition):
        print("True")
        lowest_price = current_price
    else:
        print("False")
print(lowest_price)
# Out:
# True
# True
# True
# False
# False
# False
# False
# False
# False
# False
# False
# 4

# %%
# for loop
price_list = [9,7,4,6,7,8,6,8,4,7,5]
lowest_price = 1000
for idx in range(len(price_list)):
    current_price = price_list[idx]
    condition = current_price < lowest_price
    if (condition):
        print("True")
        lowest_price = current_price
    else:
        print("False")
print(lowest_price)
# Out:
# True
# True
# True
# False
# False
# False
# False
# False
# False
# False
# False
# 4

# %% [markdown]
# ## tuple
#
# * The tuple is written as a list of comma-separated values (items) between parentheses.
# * The tuple cannot be modified.

# %%
a = (1, 2, 3, 4)
print(type(a))
print(a, len(a))
print(a[0], a[-1])
print(max(a), min(a))
# Out:
# <class 'tuple'>
# (1, 2, 3, 4) 4
# 1 4
# 4 1

# %%
list_a = list(a)
print(list_a)
list_a.append(3)
print(list_a)
print(a)

b = tuple(list_a)
print(b)
# Out:
# [1, 2, 3, 4]
# [1, 2, 3, 4, 3]
# (1, 2, 3, 4)
# (1, 2, 3, 4, 3)

# %% [markdown]
# ## Functions
# Python functions are defined using the `def` keyword.

# %%
def greet(s):
    print("hello, ", s)
greet("Cat")
# Out:
# hello,  Cat

# %%
def greet(s):
    print("hello, ", s)
    return s*2

c = greet(3)
print(c)
# Out:
# hello,  3
# 6

# %% [markdown]
# ## example: univariate linear model
# $a=wx+b$
#
# for example
#
# $a=2x+3$

# %%
#one argument
def linear(x):
    a = 2*x+3
    return a

for x in [-1, 0, 1]:
    print(linear(x))
# Out:
# 1
# 3
# 5

# %%
#three arguments
def linear(x, w, b):
    a = w*x+b
    return a

for x in [-1, 0, 1]:
    print(linear(x, 2, 3))
# Out:
# 1
# 3
# 5

# %%
#argument with default values
def linear(x, w=2, b=3):
    a = w*x+b
    return a

for x in [-1, 0, 1]:
    print(linear(x, 2, 3))
print('-'*20)

for x in [-1, 0, 1]:
    print(linear(x))
# Out:
# 1
# 3
# 5
# --------------------
# 1
# 3
# 5

# %%
#argument with default values
def linear(x, w=2, b):
    a = w*x+b
    return a
# Out:
#   File "<ipython-input-114-df70d8d50ceb>", line 2
#     def linear(x, w=2, b):
#                         ^
# SyntaxError: non-default argument follows default argument

# %% [markdown]
# # module

# %%
import os
print(os) 

print('-'*20)

print(os.listdir())
# Out:
# <module 'os' from 'C:\\Programs\\Python\\lib\\os.py'>
# --------------------
# ['.ipynb_checkpoints', '.vscode', 'homework.ipynb', 'images', 'lecture.ipynb', 'lecture2.ipynb', 'Lecture2.pdf', 'Lecture2.pptx', 'python-intro.html', 'python-intro.ipynb', 'python-intro.pdf', 'test.py']

# %%
from os import listdir
listdir()
# Out:
# ['.ipynb_checkpoints',
#  '.vscode',
#  'homework.ipynb',
#  'images',
#  'lecture.ipynb',
#  'lecture2.ipynb',
#  'Lecture2.pdf',
#  'Lecture2.pptx',
#  'python-intro.html',
#  'python-intro.ipynb',
#  'python-intro.pdf',
#  'test.py']

# %%
from os import listdir as listdir_os
listdir_os()
# Out:
# ['.ipynb_checkpoints',
#  '.vscode',
#  'homework.ipynb',
#  'images',
#  'lecture.ipynb',
#  'lecture2.ipynb',
#  'Lecture2.pdf',
#  'Lecture2.pptx',
#  'python-intro.html',
#  'python-intro.ipynb',
#  'python-intro.pdf',
#  'test.py']

# %% [markdown]
# ## Matplotlib
#
#
# Matplotlib is a plotting library.
#
# `import matplotlib.pyplot as plt`
#
# allows you to plot 2D data.
#
# install with `pip install matplotlib`

# %%
import matplotlib.pyplot as plt

# %%
x = [1,2,5,8,9]
y = [1,2,5,8,9]

plt.plot(x, y, '-') #shit + tab to show the doc

# %%
plt.plot(x, y, 'r--') #shit + tab to show the doc

# %%
x = [1,2,5,8,9]
y = [1,2,5,8,9]

x_noise = [1,2,5,7,9]
y_noise = [1,2,2.5,8,9]

plt.plot(x, y, '-')
plt.plot(x_noise, y_noise, 'ro')

# %%
#a = 2x + 3

x = [1,2,5,8,9]

a1 = [linear(x_i, 2, 1) for x_i in x]

#a = -x + 9
a2 = [linear(x_i, -1, 9) for x_i in x]

plt.plot(x, a1, '-') 
plt.plot(x, a2, 'r-') 
plt.legend(['a = 2x + 3', 'a = -x + 9'])

# %%
plt.plot(x, a1, '-', x, a2, 'r-') #
plt.legend(['a = 2x + 3', 'a = -x + 9'])

# %%
plt.plot(x, a1, '-', x, a2, 'r-') #
plt.text(6,10,"hello matplot")
plt.grid()

# %%
from PIL import Image

img = Image.open("images/lena.jpg")
plt.imshow(img)

# %% [markdown]
# ### Subplots
#
# You can plot different things in the same figure using the subplot function.

# %%
plt.subplot(1,2,1)
plt.subplot(1,2,2)
# Out:
# <AxesSubplot:>

# %%
plt.subplot(1,2,1)
plt.plot(x, a1, '-', x, a2, 'r-') #
plt.legend(['a = 2x + 3', 'a = -x + 9'])


plt.subplot(1,2,2)
img = Image.open("images/lena.jpg")
plt.imshow(img)

# %%
plt.subplot(2,1,1)
plt.plot(x, a1, '-', x, a2, 'r-') #
plt.legend(['a = 2x + 3', 'a = -x + 9'])


plt.subplot(2,1,2)
img = Image.open("images/lena.jpg")
plt.imshow(img)
